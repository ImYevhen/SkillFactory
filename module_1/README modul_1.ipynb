# %% [markdown]
# # ЮНИТ 1. ПРОЕКТ 1. КТО ХОЧЕТ СТАТЬ МИЛЛИОНЕРОМ КИНОПРОКАТА?
# ### UNIT 1. PROJECT 1. WHO WANTS TO BECOME A MILLIONAIRE OF FILM RENTAL?
#
#
# #### 1. Какой частью своей работы вы остались особенно довольны?
# Первые 15 вопросов дались не так сложно. Иногда получалось с первого раза получить ответ.
# #### 2. Что не получилось сделать так, как хотелось? Над чем ещё стоит поработать?
# Очень долго разбирался с функциями. Задания где применялись функции всегда забирали много времени.
# Не получилось сделать все за 4 часа как было написано в описании. Я потратил часов 8-10.
# #### 3. Что интересного и полезного вы узнали в этом модуле?
# Как можно совмещать работу функций и библиотеки пандас.
# #### 4. Что является вашим главным результатом при прохождении этого проекта?
# Усидчиво гуглил и находил ответ на те вопросы которые долго не мог найти ответ сам.
# #### 5. Планируете ли вы менять стратегию изучения последующих модулей?
# Да, я не буду оставлять на последний день сдачу проекта.
